# %%
import os, sys
sys.path.append(os.path.abspath('..'))

from src.data.datasets import ACDCDataset
import pydicom
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
acdc_data_tag1 = ACDCDataset('D:/data/training_sub/', recompute=True, tagged=True)
fig  = plt.figure(0, (15, 10), dpi = 200)
grid = ImageGrid(fig, 111, nrows_ncols=(2, 5), axes_pad=0.0)  

for i in range(10):
    im_plt = grid[i].imshow(acdc_data_tag1[i][0][0], cmap='gray')
    grid[i].get_yaxis().set_ticks([])
    grid[i].get_xaxis().set_ticks([])
    grid[i].set_axis_off()
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.24it/s]

# %%
len(acdc_data_tag1)
# Out:
# 49
